# %% [markdown]
# # Módulo 7:  Exportación y generación de reporte

# %% [markdown]
# # Librerias

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Carga de archivos

# %%
DH = pd.read_csv('output_mod6.csv', sep=',')
DH
# Out:
#              East        North  Elevation     bo    cpy     py alte mine  dom  \
# 0     156911.7393  93193.44188    3827.13  0.000  0.564  1.199  BTK  CPY    3
# 1     156908.3362  93214.70964    3768.98  0.019  0.671  3.247  BTK  CPY    3
# 2     156905.6440  93233.72129    3712.19  0.097  0.582  1.035  BTK   BN    3
# 3     156903.2416  93252.82611    3653.51  0.193  0.487  0.780  BTK  CPY    3
# 4     156901.0979  93270.77183    3598.07  0.058  1.036  2.730  BTK  CPY    3
# ...           ...          ...        ...    ...    ...    ...  ...  ...  ...
# 1270  156988.2447  92051.49218    2849.81  0.039  0.947  0.063  BTK  CPY    3
# 1271  157005.5199  92071.95481    2753.56  0.001  1.000  0.272  BTK  CPY    3
# 1272  156214.7871  91746.89044    3249.31  0.019  0.740  7.601  SCL  CPY    3
# 1273  156214.4738  91738.09338    3047.85  0.001  1.139  7.086  ANH  CPY    3
# 1274  156214.2187  91735.52669    2986.70  0.000  1.460  6.319  HOR  CPY    3
#
#       ug  Step_East
# 0      3   156900.0
# 1      3   156900.0
# 2      4   156900.0
# 3      3   156900.0
# 4      3   156900.0
# ...   ..        ...
# 1270   3   157020.0
# 1271   3   157020.0
# 1272   2   156180.0
# 1273   2   156180.0
# 1274   2   156180.0
#
# [1275 rows x 11 columns]

# %%
DH.to_csv('output.csv', index=False)

# %%
DH.describe().T
# Out:
#             count           mean         std           min           25%  \
# East       1275.0  156842.761676  653.918638  155448.72330  156390.57900
# North      1275.0   92566.381963  424.794056   91561.04008   92203.21228
# Elevation  1275.0    3340.410173  250.859647    2703.21000    3190.55000
# bo         1275.0       0.140922    0.190800       0.00000       0.00150
# cpy        1275.0       1.073958    0.561443       0.00000       0.71550
# py         1275.0       1.344159    1.987731       0.00000       0.17800
# dom        1275.0       2.814118    0.397150       1.00000       3.00000
# ug         1275.0       2.669804    1.057969       1.00000       2.00000
# Step_East  1275.0  156843.717647  658.259669  155460.00000  156420.00000
#
#                     50%           75%           max
# East       156764.98550  157241.01415  158454.74320
# North       92553.96893   92879.35623   93569.02053
# Elevation    3359.16000    3538.83500    3827.69000
# bo              0.05800       0.21500       1.66100
# cpy             0.99000       1.27850       6.84900
# py              0.60600       1.61850      16.52000
# dom             3.00000       3.00000       3.00000
# ug              3.00000       4.00000       4.00000
# Step_East  156780.00000  157260.00000  158460.00000

# %%
DH.describe().T.to_csv('stats.csv')

# %%
DH['bo'].hist(bins=20)
plt.savefig('hist.png')
plt.savefig('hist.jpg')
